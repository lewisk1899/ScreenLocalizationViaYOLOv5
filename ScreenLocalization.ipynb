# %%
import torch
import pandas as pd
import numpy as np
import cv2
import os, time, random
import shutil as sh
from tqdm.notebook import tqdm

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
# %mkdir ScreenLocalization
# %cd ScreenLocalization
# %mkdir data
# Out:
# mkdir: cannot create directory ‘ScreenLocalization’: File exists
# /content/ScreenLocalization
# mkdir: cannot create directory ‘data’: File exists

# %%
# %cd ../gdrive/MyDrive/ScreenLocalizationDataset/
# Out:
# /content/gdrive/MyDrive/ScreenLocalizationDataset

# %%
# !unzip ScreenData1.zip
# !unzip ScreenData2.zip
# !unzip ScreenData3.zip
# !unzip ScreenData4.zip
# !unzip ScreenData5.zip
# !unzip ScreenData6.zip
# !unzip ScreenData7.zip
# !unzip ScreenData8.zip

# %%
# %cd ../../../ScreenLocalization

# %%
# %cd ../gdrive/MyDrive/ScreenLocalizationDataset/

# %%
# %mkdir train
# %mkdir valid

# %%
# %mv ScreenData1/* train/
# %mv ScreenData2/* train/
# %mv ScreenData3/* train/
# %mv ScreenData4/* train/
# %mv ScreenData5/* train/
# %mv ScreenData6/* train/
# %mv ScreenData7/* valid/
# %mv ScreenData8/* train/

# %%
# %mkdir ../../../ScreenLocalization/data/train
# %mkdir ../../../ScreenLocalization/data/valid

# %%
# %cp -a train/. ../../../ScreenLocalization/data/train
# %cp -a valid/. ../../../ScreenLocalization/data/valid

# %%
# %cd ../../../ScreenLocalization/

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# !which pip

# %%
# !pip install -r yolov5/requirements.txt

# %%
# %cp ../gdrive/MyDrive/ScreenLocalizationDataset/screen.yaml yolov5/

# %%
# %cd yolov5

# %%
# !python train.py --cfg yolov5s.yaml --batch 64 --epochs 100 --data screen.yaml --weights yolov5s.pt --workers 24 --name screen_detection

# %%
# %cp -r runs/ ../../gdrive/MyDrive/ScreenLocalizationRuns/

# %%
# %ls
# Out:
# CONTRIBUTING.md  hubconf.py    README.md          setup.cfg       val.py
# data/            LICENSE       requirements.txt*  train.py        yolov5s.pt
# detect.py        models/       runs/              tutorial.ipynb
# export.py        __pycache__/  screen.yaml        utils/
